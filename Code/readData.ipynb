# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.28/00

# %%
c = ROOT.TCanvas("Canvas", "Title", 800, 600)
h1 = ROOT.TH1F("SiPM26", "hist_26", 100, 0,1000)
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas

# %%
h1.Draw()
c.Draw()
